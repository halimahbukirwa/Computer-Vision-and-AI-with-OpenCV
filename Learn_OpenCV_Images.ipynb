# %% [markdown]
# <a href="https://colab.research.google.com/github/halimahbukirwa/Computer-Vision-and-AI-with-OpenCV/blob/main/Learn_OpenCV_Images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %% [markdown]
# ## **Reading and image**

# %%
#downloading it
# !wget "https://cdn.pixabay.com/photo/2023/02/04/09/20/castle-7766794_960_720.jpg"
# Out:
# --2023-03-03 02:30:51--  https://cdn.pixabay.com/photo/2023/02/04/09/20/castle-7766794_960_720.jpg
# Resolving cdn.pixabay.com (cdn.pixabay.com)... 104.18.14.16, 104.18.15.16, 2606:4700::6812:e10, ...
# Connecting to cdn.pixabay.com (cdn.pixabay.com)|104.18.14.16|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 201871 (197K) [image/jpeg]
# Saving to: ‘castle-7766794_960_720.jpg.1’
#
# castle-7766794_960_ 100%[===================>] 197.14K  --.-KB/s    in 0.03s
#
# 2023-03-03 02:30:51 (6.98 MB/s) - ‘castle-7766794_960_720.jpg.1’ saved [201871/201871]

# %%
#reading the images
color_img = cv2.imread('/content/castle-7766794_960_720.jpg', 1)
gray_img = cv2.imread('/content/castle-7766794_960_720.jpg',0)
default_img = cv2.imread('/content/castle-7766794_960_720.jpg',-1)

# %% [markdown]
# ## **Displaying the Image**

# %%
#cv2.imshow('Color Image', color_img)
#cv2.imshow('Default Image', default_img)
#cv2.imshow('Gray Image', gray_img)

# %% [markdown]
# The function `cv2.imshow()` opens a window displaying the image and therefore cannot be used in a Colab notebook. We can instead use Matplotlib to display image in the notebook. To use Matplotlib, we need to import the `matplotlib` library.

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(color_img)
plt.axis('off')
plt.show()

# %% [markdown]
# The displayed image isn't as expected. This happens because OpenCV represents RGB images as multi-dimensional NumPy array but in the reverse order. This means that images are actually represented in BGR order rather than RGB. This can be corrected by converting BGR to RGB

# %%
plt.axis('off')
plt.imshow(cv2.cvtColor(color_img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
plt.axis('off')
plt.imshow(cv2.cvtColor(gray_img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
plt.axis('off')
plt.imshow(cv2.cvtColor(default_img, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# ## **Writing an image**

# %%
cv2.imwrite('gray_img.png', gray_img)
# Out:
# True
